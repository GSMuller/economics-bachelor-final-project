# %% [markdown]
# # Síntese Comparativa
#
# Padrão-Ouro vs Derivativos vs Blockchain

# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.visualization import plot_comparative_evolution, plot_correlation_heatmap

# %% [markdown]
# ## 1. Comparação Temporal de Volatilidade

# %% [markdown]
# ## 2. Mecanismos de Ancoragem

# %% [markdown]
# ## 3. Coordenação entre Agentes
