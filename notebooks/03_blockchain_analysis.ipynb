# %% [markdown]
# # Análise de Blockchain e Bitcoin
#
# Bitcoin como reserva de valor descentralizada

# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from src.data_collection import fetch_crypto_prices
from src.defi_analysis import calculate_volatility_comparison
from src.visualization import plot_time_series
from src.config import CRYPTO_SYMBOLS, BITCOIN_GENESIS

# %% [markdown]
# ## 1. Preços de Criptomoedas

# %%
crypto_prices = fetch_crypto_prices(CRYPTO_SYMBOLS, "2010-01-01", "2024-12-31")
crypto_prices.head()

# %% [markdown]
# ## 2. Evolução do Bitcoin

# %%
plot_time_series(
    crypto_prices["BTC"],
    "Preço do Bitcoin 2010-2024",
    "Preço (USD)"
)

# %% [markdown]
# ## 3. Volatilidade Comparada
